# %% [markdown]
# *데이터명 : 국민연금공단_국내주식 투자정보
# *데이터 특징
#     1. 출처 : 공공데이터포털(https://www.data.go.kr/data/3070507/fileData.do)
#     2. 분야 : 금융
#     3. 내용 : 국민연금의 국내주식 종목별 투자 현황입니다. 연도말 기준 국내주식 투자 종목별 평가액, 자산군 내 비중, 지분율 등 투자 현황에 대한 정보 (단위: 억 원, %)를 제공합니다.
#     4. 국민연금에서 투자하고 있는 종목이 무엇인지 파악하고, 실제 주가를 확인하여 수익률이 높은 종목들에 투자하고 있는지 분석하고 싶었습니다. 이를 통해 나도 이러한 종목들에 투자한다면, 수익을 올릴 수 있지 않을까 싶어 이 데이터를 찾게 되었습니다.

# %% [markdown]
# *데이터명 : Death rate of countries and its causes
# *데이터 특징
#     1. 출처 : kaggle(https://www.kaggle.com/datasets/bilalwaseer/death-rate-of-countries-and-its-causes/data)
#     2. 분야 : 의료
#     3. 내용 : 1990년부터 2019년까지 전세계의 사망률과 그 원인에 대한 데이터셋입니다.
#     4. 대한민국 사람들의 가장 높은 사망률을 기록한 원인이 무엇인지 분석하고, 이를 예방할 수 있을 것입니다.
